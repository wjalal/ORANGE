# %%
import os
import pandas as pd
import numpy as np
import glob
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.

# %%
data_folder = 'TPM_dataCSV/'
organs = ["adipose_subcutaneous","artery_aorta","artery_coronary","brain_cerebellum","brain_cortex","colon_sigmoid","heart_atrial_appendage","liver","lung","nerve_tibial","pancreas","skin_sun_exposed_lower_leg"]

# %%
def load_data_for_organ(organ_name):
    csv_file = glob.glob(os.path.join(data_folder, f'gene_tpm_v10_{organ_name}.csv'))[0]
    df = pd.read_csv(csv_file)
    expression_data = df.iloc[:, 3:].transpose()
    expression_data['organ'] = organ_name 
    return expression_data

# %%
all_data = pd.DataFrame()
for organ in organs:
    organ_data = load_data_for_organ(organ)
    all_data = pd.concat([all_data, organ_data], axis=0)
print(all_data)
# Out:
#                                  0         1    2         3         4  \
# GTEX-111CU-1826-SM-5GZYN  0.000000   3.06160  0.0  0.000000  0.000000
# GTEX-111FC-0226-SM-5N9B8  0.000000   3.95025  0.0  0.042660  0.000000
# GTEX-111VG-2326-SM-5N9BK  0.000000   3.19860  0.0  0.000000  0.000000
# GTEX-111YS-2426-SM-5GZZQ  0.000000   2.98399  0.0  0.000000  0.037800
# GTEX-1122O-2026-SM-9YFMG  0.000000   2.59251  0.0  0.028196  0.000000
# ...                            ...       ...  ...       ...       ...
# GTEX-ZYW4-0126-SM-5E44A   0.000000   2.08963  0.0  0.059341  0.000000
# GTEX-ZYY3-0126-SM-5GZY5   0.000000  14.85090  0.0  0.000000  0.045574
# GTEX-ZZ64-1726-SM-5GZYB   0.000000   8.18698  0.0  0.000000  0.000000
# GTEX-ZZPT-0226-SM-5E43X   0.000000   4.00980  0.0  0.048417  0.034396
# GTEX-ZZPU-2526-SM-GOQZ3   0.017791   5.09581  0.0  0.000000  0.000000
#
#                                  5         6         7         8         9  \
# GTEX-111CU-1826-SM-5GZYN  0.000000  0.071885  0.038825  0.049414  0.176161
# GTEX-111FC-0226-SM-5N9B8  0.000000  0.052253  0.000000  0.071839  0.000000
# GTEX-111VG-2326-SM-5N9BK  0.000000  0.028885  0.015601  0.039712  0.082584
# GTEX-111YS-2426-SM-5GZZQ  0.000000  0.000000  0.052802  0.044802  0.053239
# GTEX-1122O-2026-SM-9YFMG  0.087205  0.017268  0.046634  0.023741  0.007053
# ...                            ...       ...       ...       ...       ...
# GTEX-ZYW4-0126-SM-5E44A   0.061178  0.000000  0.078517  0.000000  0.029688
# GTEX-ZYY3-0126-SM-5GZY5   0.066137  0.078578  0.042441  0.027008  0.032094
# GTEX-ZZ64-1726-SM-5GZYB   0.000000  0.033000  0.017824  0.045369  0.080870
# GTEX-ZZPT-0226-SM-5E43X   0.099831  0.088959  0.112110  0.000000  0.036334
# GTEX-ZZPU-2526-SM-GOQZ3   0.109858  0.174032  0.011749  0.149539  0.088851
#
#                           ...     59024     59025     59026     59027  \
# GTEX-111CU-1826-SM-5GZYN  ...  0.736558  2.584200  0.715810   3951.56
merged_data = pd.merge(all_data,phenotype, on='SUBJID', how='left')
merged_data.set_index('SUBJID', inplace=True)
merged_data.dropna(inplace=True)
print(merged_data)
# Out:
#                    0         1    2         3         4         5         6  \
# SUBJID
# GTEX-111CU  0.000000   3.06160  0.0  0.000000  0.000000  0.000000  0.071885
# GTEX-111FC  0.000000   3.95025  0.0  0.042660  0.000000  0.000000  0.052253
# GTEX-111VG  0.000000   3.19860  0.0  0.000000  0.000000  0.000000  0.028885
# GTEX-111YS  0.000000   2.98399  0.0  0.000000  0.037800  0.000000  0.000000
# GTEX-1122O  0.000000   2.59251  0.0  0.028196  0.000000  0.087205  0.017268
# ...              ...       ...  ...       ...       ...       ...       ...
# GTEX-ZYW4   0.000000   2.08963  0.0  0.059341  0.000000  0.061178  0.000000
# GTEX-ZYY3   0.000000  14.85090  0.0  0.000000  0.045574  0.066137  0.078578
# GTEX-ZZ64   0.000000   8.18698  0.0  0.000000  0.000000  0.000000  0.033000
# GTEX-ZZPT   0.000000   4.00980  0.0  0.048417  0.034396  0.099831  0.088959
# GTEX-ZZPU   0.017791   5.09581  0.0  0.000000  0.000000  0.109858  0.174032
#
#                    7         8         9  ...     59024     59025     59026  \
# SUBJID                                    ...
# GTEX-111CU  0.038825  0.049414  0.176161  ...  0.736558  2.584200  0.715810
# GTEX-111FC  0.000000  0.071839  0.000000  ...  1.070820  0.626156  0.000000
# GTEX-111VG  0.015601  0.039712  0.082584  ...  1.183870  0.000000  0.000000
# GTEX-111YS  0.052802  0.044802  0.053239  ...  1.335610  0.780989  0.648991
# GTEX-1122O  0.046634  0.023741  0.007053  ...  0.353875  0.000000  0.000000
# ...              ...       ...       ...  ...       ...       ...       ...
# GTEX-ZYW4   0.078517  0.000000  0.029688  ...  2.234320  0.000000  1.447590
# GTEX-ZYY3   0.042441  0.027008  0.032094  ...  0.000000  1.883210  0.782462
# GTEX-ZZ64   0.017824  0.045369  0.080870  ...  0.000000  0.000000  0.657215
# GTEX-ZZPT   0.112110  0.000000  0.036334  ...  0.000000  2.842660  1.181110
# GTEX-ZZPU   0.011749  0.149539  0.088851  ...  0.445799  0.521359  0.433242
#
#                59027     59028     59029    59030     59031     59032  \
# SUBJID
# GTEX-111CU   3951.56   3687.20   5.89247  19690.6  0.000000  0.747390
# GTEX-111FC   3412.46   3271.62   3.74786  22023.9  0.000000  2.716410
# GTEX-111VG   2374.52   2449.22   5.91938  13361.4  0.618844  0.600643
# GTEX-111YS   6106.99   5330.43  16.69510  37726.2  0.698157  2.032870
# GTEX-1122O   6620.23   6276.19  15.92440  34497.1  0.369960  0.359079
# ...              ...       ...       ...      ...       ...       ...
# GTEX-ZYW4    8123.10  12099.80  31.28050  15140.7  2.335880  1.511450
# GTEX-ZYY3    6687.76  12316.60  44.28280  14696.6  3.366960  1.633970
# GTEX-ZZ64    7921.64  10899.30  35.16580  19689.5  0.000000  2.058630
# GTEX-ZZPT    6470.48   6516.84  17.01480  28450.7  0.000000  1.849820
# GTEX-ZZPU   10214.20  11752.80  40.12190  25368.8  5.126690  1.809420
#
#                                  organ
# SUBJID
# GTEX-111CU        adipose_subcutaneous
# GTEX-111FC        adipose_subcutaneous
# GTEX-111VG        adipose_subcutaneous
# GTEX-111YS        adipose_subcutaneous
# GTEX-1122O        adipose_subcutaneous
# ...                                ...
# GTEX-ZYW4   skin_sun_exposed_lower_leg
# GTEX-ZYY3   skin_sun_exposed_lower_leg
# GTEX-ZZ64   skin_sun_exposed_lower_leg
# GTEX-ZZPT   skin_sun_exposed_lower_leg
# GTEX-ZZPU   skin_sun_exposed_lower_leg
#
# [5510 rows x 59034 columns]

# %%
extreme_agers = pd.read_csv('extreme_agers.csv', header=None, names=['SUBJID'])
filtered_data = merged_data[merged_data.index.isin(extreme_agers['SUBJID'])]
print(filtered_data)
# Out:
#                    0         1    2         3         4         5         6  \
# SUBJID
# GTEX-1122O  0.000000   2.59251  0.0  0.028196  0.000000  0.087205  0.017268
# GTEX-117YX  0.000000   2.33185  0.0  0.000000  0.034799  0.000000  0.060001
# GTEX-11DYG  0.000000   5.33653  0.0  0.000000  0.000000  0.000000  0.025441
# GTEX-11EMC  0.019145   5.80783  0.0  0.076448  0.000000  0.039407  0.023410
# GTEX-11I78  0.000000   4.06815  0.0  0.104848  0.000000  0.000000  0.000000
# ...              ...       ...  ...       ...       ...       ...       ...
# GTEX-ZF3C   0.019418   3.86805  0.0  0.000000  0.027542  0.000000  0.000000
# GTEX-ZLWG   0.018630  12.97630  0.0  0.000000  0.000000  0.038346  0.022780
# GTEX-ZP4G   0.000000   1.56196  0.0  0.000000  0.000000  0.000000  0.051472
# GTEX-ZTPG   0.000000   4.18033  0.0  0.052118  0.000000  0.000000  0.000000
# GTEX-ZYFG   0.000000   5.64146  0.0  0.079005  0.000000  0.000000  0.193547
#
#                    7         8         9  ...     59024     59025    59026  \
# SUBJID                                    ...
# GTEX-1122O  0.046634  0.023741  0.007053  ...  0.353875  0.000000  0.00000
# GTEX-117YX  0.178237  0.041245  0.024506  ...  1.844370  0.000000  0.00000
# GTEX-11DYG  0.000000  0.034977  0.000000  ...  0.000000  0.000000  0.00000
# GTEX-11EMC  0.025288  0.016092  0.000000  ...  1.439220  1.122110  0.00000
# GTEX-11I78  0.121388  0.022071  0.039341  ...  0.657959  0.000000  0.00000
# ...              ...       ...       ...  ...       ...       ...      ...
# GTEX-ZF3C   0.012824  0.032643  0.038791  ...  0.000000  0.000000  0.00000
# GTEX-ZLWG   0.036910  0.031318  0.074432  ...  0.000000  0.000000  0.00000
# GTEX-ZP4G   0.013900  0.053074  0.000000  ...  0.000000  0.000000  0.00000
# GTEX-ZTPG   0.017240  0.000000  0.013037  ...  0.654116  0.764983  0.00000
# GTEX-ZYFG   0.065335  0.099784  0.088933  ...  1.983150  1.159640  1.44547
#
#                59027     59028     59029    59030     59031     59032  \
# SUBJID
# GTEX-1122O   6620.23   6276.19  15.92440  34497.1  0.369960  0.359079
# GTEX-117YX   3790.70   3163.51   3.68873  29066.5  0.000000  1.871490
# GTEX-11DYG   2576.96   1864.21   8.86320  13143.3  1.635190  0.000000
# GTEX-11EMC   3084.11   2306.24   8.15560  15878.4  1.003100  0.486796
# GTEX-11I78   3504.63   4155.80  11.84330  26122.4  0.687866  1.335270
# ...              ...       ...       ...      ...       ...       ...
# GTEX-ZF3C    9114.50  10910.40  33.57370  13315.7  0.508692  0.493731
# GTEX-ZLWG    5324.75   6646.08  28.47590  16719.6  0.488037  0.947365
# GTEX-ZP4G    2525.47   5950.71  29.00720  11435.8  1.654130  0.535160
# GTEX-ZTPG    6272.43   8252.65  32.70580  15823.7  2.051550  1.991210
# GTEX-ZYFG   14348.50  24479.80  93.20810  35994.6  3.109940  2.515390
#
#                                  organ
# SUBJID
# GTEX-1122O        adipose_subcutaneous
# GTEX-117YX        adipose_subcutaneous
# GTEX-11DYG        adipose_subcutaneous
# GTEX-11EMC        adipose_subcutaneous
# GTEX-11I78        adipose_subcutaneous
# ...                                ...
# GTEX-ZF3C   skin_sun_exposed_lower_leg
# GTEX-ZLWG   skin_sun_exposed_lower_leg
# GTEX-ZP4G   skin_sun_exposed_lower_leg
# GTEX-ZTPG   skin_sun_exposed_lower_leg
# GTEX-ZYFG   skin_sun_exposed_lower_leg
#
# [1093 rows x 59034 columns]

# %%
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
extreme_agers_tsne_data = tsne.fit_transform(filtered_data.drop(columns=['organ']))
extreme_agers_tsne = pd.DataFrame(data=extreme_agers_tsne_data, columns=['Dim1', 'Dim2'])
extreme_agers_tsne['organ'] = filtered_data['organ'].values
print(extreme_agers_tsne)
# Out:
#            Dim1       Dim2                       organ
# 0    -11.220280   0.224488        adipose_subcutaneous
# 1     -7.546268   5.096807        adipose_subcutaneous
# 2     16.529322  -2.655332        adipose_subcutaneous
# 3     -0.255281   7.228288        adipose_subcutaneous
# 4      1.816343   5.079539        adipose_subcutaneous
# ...         ...        ...                         ...
# 1088 -26.751186 -38.549236  skin_sun_exposed_lower_leg
# 1089 -22.930538 -38.907589  skin_sun_exposed_lower_leg
# 1090 -22.382011 -40.589455  skin_sun_exposed_lower_leg
# 1091 -20.677105 -33.633797  skin_sun_exposed_lower_leg
# 1092 -23.109728 -22.437737  skin_sun_exposed_lower_leg
#
# [1093 rows x 3 columns]

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Dim1', y='Dim2', hue='organ', palette="tab20", data=extreme_agers_tsne, s=20, alpha=1)
plt.title("t-SNE of TPM Expression Data \n for Different Organs in Extreme Agers")
plt.legend(title="Organ", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
plt.savefig('extreme_agers_tsne.png')
plt.show()
plt.close()
